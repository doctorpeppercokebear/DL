# %% [markdown]
# # Reference
# - Sebastian Raschka "GAN-MLP-MNIST", Colab Notebook, https://github.com/rasbt/stat479-deep-learning-ss19/blob/master/L17_gans/code/gan-mlp-mnist.ipynb

# %% [markdown]
# # Vanilla Generative Adversarial Networks (GAN)

# %% [markdown]
# Implementation of a standard GAN using a Multi-layer Perceptron for both the discriminator and generator.

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
num_epochs = 100
batch_size = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data',
                              train=False,
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size,
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()


        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh()
        )

        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )


    def generator_forward(self, z):
        img = self.generator(z)
        return img

    def discriminator_forward(self, img):
        pred = self.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %%
model
# Out:
# GAN(
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=128, out_features=784, bias=True)
#     (4): Tanh()
#   )
#   (discriminator): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#     (4): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training

# %%
start_time = time.time()

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):



        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device)
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)


        ### FORWARD AND BACK PROP


        # --------------------------
        # Train Generator
        # --------------------------

        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)

        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)

        gener_loss = F.binary_cross_entropy(discr_pred, valid)

        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()

        # --------------------------
        # Train Discriminator
        # --------------------------

        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)

        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)

        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()

        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())


        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f'
                   %(epoch+1, num_epochs, batch_idx,
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6817/0.7123
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 4.6622/0.0372
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 1.6639/0.1155
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 1.8110/0.1363
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 1.1353/0.3299
# Time elapsed: 0.13 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 2.3664/0.1204
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 1.0648/0.3658
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 1.6859/0.3649
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 1.0881/0.4665
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 1.0053/0.5029
# Time elapsed: 0.25 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 0.8280/0.4607
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 1.6671/0.4053
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 1.1644/0.4018
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 1.3412/0.4064
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 1.3731/0.3863
# Time elapsed: 0.37 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 1.1630/0.3796
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 0.9628/0.5410
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 1.5710/0.3576
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 1.1517/0.4175
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 1.4443/0.4803
# Time elapsed: 0.49 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 1.0938/0.5339
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 0.9435/0.4315
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 2.2339/0.3626
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 1.2989/0.3709
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 0.9952/0.4622
# Time elapsed: 0.62 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 1.0752/0.5196
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 0.9558/0.5048
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 1.5243/0.4386
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 1.5627/0.4870
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 0.8251/0.5520
# Time elapsed: 0.74 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 1.1111/0.4830
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 0.8590/0.5393
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 1.3939/0.4409
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 0.9805/0.4811
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 1.6719/0.5285
# Time elapsed: 0.86 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 0.9995/0.5314
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 1.2264/0.5017
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 1.1018/0.5341
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 0.8925/0.5740
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 0.8771/0.5447
# Time elapsed: 0.98 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 1.2025/0.5657
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss: 1.1063/0.4580
# Epoch: 009/100 | Batch 200/469 | Gen/Dis Loss: 1.3497/0.3071
# Epoch: 009/100 | Batch 300/469 | Gen/Dis Loss: 0.9497/0.5452
# Epoch: 009/100 | Batch 400/469 | Gen/Dis Loss: 0.9652/0.5239
# Time elapsed: 1.11 min
# Epoch: 010/100 | Batch 000/469 | Gen/Dis Loss: 0.8397/0.5698
# Epoch: 010/100 | Batch 100/469 | Gen/Dis Loss: 1.2535/0.5754
# Epoch: 010/100 | Batch 200/469 | Gen/Dis Loss: 1.7088/0.4558
# Epoch: 010/100 | Batch 300/469 | Gen/Dis Loss:
min
# Epoch: 079/100 | Batch 000/469 | Gen/Dis Loss: 0.8543/0.6346
# Epoch: 079/100 | Batch 100/469 | Gen/Dis Loss: 0.8531/0.6290
# Epoch: 079/100 | Batch 200/469 | Gen/Dis Loss: 0.7792/0.6577
# Epoch: 079/100 | Batch 300/469 | Gen/Dis Loss: 0.8013/0.6788
# Epoch: 079/100 | Batch 400/469 | Gen/Dis Loss: 0.9288/0.6147
# Time elapsed: 9.83 min
# Epoch: 080/100 | Batch 000/469 | Gen/Dis Loss: 0.9201/0.6573
# Epoch: 080/100 | Batch 100/469 | Gen/Dis Loss: 0.7456/0.6344
# Epoch: 080/100 | Batch 200/469 | Gen/Dis Loss: 0.9783/0.6619
# Epoch: 080/100 | Batch 300/469 | Gen/Dis Loss: 0.8243/0.6448
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 1.0641/0.6155
# Time elapsed: 9.95 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 0.8271/0.6523
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.9404/0.6597
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 0.8224/0.6297
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 0.9743/0.6720
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 0.7425/0.6418
# Time elapsed: 10.08 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.8027/0.6579
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 0.8244/0.6891
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.8503/0.6597
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.8534/0.6186
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.8081/0.6578
# Time elapsed: 10.20 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 1.1594/0.6635
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 0.8398/0.6723
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.7824/0.6389
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 0.7974/0.6448
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.8145/0.6296
# Time elapsed: 10.33 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.7532/0.6487
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.7915/0.6606
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.8203/0.6244
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.8254/0.6729
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 1.0978/0.6305
# Time elapsed: 10.46 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.9064/0.5953
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 1.2128/0.6252
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.8299/0.6350
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 1.0276/0.5809
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.7017/0.6449
# Time elapsed: 10.58 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.8001/0.6641
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.8237/0.6211
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.7466/0.6968
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.8667/0.6058
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.8519/0.6487
# Time elapsed: 10.71 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.9508/0.6706
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.9050/0.6447
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.8078/0.6264
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.8887/0.6271
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.7793/0.6396
# Time elapsed: 10.83 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.8732/0.6687
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.7530/0.6639
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 1.1570/0.6210
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.9518/0.6117
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.7776/0.6627
# Time elapsed: 10.95 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 1.0111/0.6224
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.8490/0.6099
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.8618/0.6492
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.8344/0.6376
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.7553/0.6717
# Time elapsed: 11.08 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.8431/0.6570
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.7402/0.6508
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.7829/0.6344
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.9085/0.6576
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.7748/0.6676
# Time elapsed: 11.20 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.9685/0.6575
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.7750/0.6290
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.7625/0.6501
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.7691/0.6345
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.8277/0.6624
# Time elapsed: 11.32 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.8631/0.6437
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.8866/0.6353
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 0.7879/0.6325
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.7718/0.6625
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.7783/0.6444
# Time elapsed: 11.45 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.7531/0.6509
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.8040/0.6873
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.7944/0.6596
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.8087/0.6301
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.8893/0.6464
# Time elapsed: 11.57 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.8993/0.6640
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.7621/0.6747
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.8068/0.6614
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 1.0246/0.6291
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.8124/0.6408
# Time elapsed: 11.70 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.7756/0.6550
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.7874/0.6658
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.8377/0.6653
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.7822/0.6457
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.8153/0.6544
# Time elapsed: 11.82 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 1.0666/0.6034
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.8232/0.6603
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.8511/0.6110
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.8006/0.6296
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.7668/0.7055
# Time elapsed: 11.95 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.8116/0.6514
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.9218/0.6172
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.8802/0.6263
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.8299/0.6201
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.9451/0.6326
# Time elapsed: 12.07 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.9128/0.6475
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.7889/0.6117
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 1.0988/0.6563
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.8040/0.6440
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.7733/0.6347
# Time elapsed: 12.20 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.8444/0.6624
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.8364/0.6405
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.9889/0.6398
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.9809/0.6331
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.7801/0.6387
# Time elapsed: 12.32 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.8364/0.6357
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 1.1075/0.6474
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.7796/0.6612
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.7421/0.6854
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.8383/0.6448
# Time elapsed: 12.45 min
# Total Training Time: 12.45 min

# %% [markdown]
# ## Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(gener_costs)), gener_costs, label='generator loss')
plt.plot(range(len(discr_costs)), discr_costs, label='discriminator loss')
plt.legend()
plt.show()

# %%
##########################
### VISUALIZATION
##########################


model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
